# %%
#importing pandas as pd 
import pandas as pd 
  
# Read and store content 
# of an excel file  
read_file = pd.read_excel ("../data/input/ClassList.xlsx") 
  
# Write the dataframe object 
# into csv file 
read_file.to_csv ("../data/input/class.csv",  
                  index = None, 
                  header=True) 
    
# read csv file and convert  
# into a dataframe object 
df = pd.DataFrame(pd.read_csv("../data/input/class.csv")) 
  
# show the dataframe 
df
# Out:
#     Sr No Branch Semester                                        Subject Name  \
# 0       1     CC       4TH                  Design and Analysis of Algorithms
# 1       2     CC       4TH                  Design and Analysis of Algorithms
# 2       3     CC       4TH                              Programming in Python
# 3       4     CC       4TH                              Programming in Python
# 4       5     CC       4TH                  Design and Analysis of Algorithms
# 5       6     CC       4TH                              Programming in Python
# 6       7     CC      6TH                            Network Operating System
# 7       8     CC      6TH                            Network Operating System
# 8       9     CC      6TH                                  Technical Training
# 9      10     CC      6TH                                  Technical Training
# 10     11     CC      6TH                     Agile Development Methodologies
# ...

# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel('data/sample.xlsx')

# Assuming the 'Block' column is named 'Block' and the 'Lab no.' column is named 'Lab no.'
block_col = 'BLOCK'
labno_col = 'Lab No'

# Combine the 'Block' and 'Lab no.' columns into a single string
df['block_labno'] = df[block_col].astype(str) + '-' + df[labno_col].astype(str)

# Get the unique values of the 'block_labno' column
unique_block_labno = df['block_labno'].unique()

# Print the unique 'block_labno' values
for block_labno in unique_block_labno:
    print(block_labno)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 import pandas as pd
#       3 # Read the Excel file
# ----> 4 df = pd.read_excel('data/sample.xlsx')
#       6 # Assuming the 'Block' column is named 'Block' and the 'Lab no.' column is named 'Lab no.'
#       7 block_col = 'BLOCK'
#
# File c:\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
# ...

# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel('../data/input/ClassList.xlsx')

# Assuming the 'Internal Examiner' column is named 'Internal Examiner'
examiner_col = 'Internal Examiner'

# Get the unique values of the 'Internal Examiner' column
unique_examiners = df[examiner_col].unique()

# Print the unique internal examiners
for examiner in unique_examiners:
    print("\'"+examiner+"\'", end=", ")
# Out:
# 'ANKUR GUPTA', 'Ms. Rubbina', 'Ms. Geetanjali Pandey', 'Dr. Ankit Garg', 'Shubham Banik', 'Ms. Pavandeep Kaur', 'Dr. Dhawan Singh', 'Ms. Bhavna Nayyar', 'Dr. Monika Singh', 'Dr. Deepti Sharma', 'Dr. Ranjan Walia',

# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel('../data/input/LabList.xlsx')

# Assuming the 'Internal Examiner' column is named 'Internal Examiner'
examiner_col = 'Lab No'

# Get the unique values of the 'Internal Examiner' column
unique_examiners = df[examiner_col].unique()

# Print the unique internal examiners
for examiner in unique_examiners:
    print("\'"+examiner+"\'", end=", ")
# Out:
# 'D2-207', 'D2-306', 'D2-307', 'D2-308', 'D2-317', 'D2-318', 'D2-408', 'D2-409', 'D2-410', 'D2-411', 'D2-412', 'D2-413', 'D2-414', 'D2-415', 'D2-416', 'D2-508', 'D2-512', 'D2-513', 'D2-514', 'D3-101', 'D3-209-A', 'D3-209', 'D3-210', 'D3-211', 'D4-101', 'D4-102', 'D4-103', 'D4-104', 'D4-106',

# %%
import pandas as pd

# Read the Excel file
df = pd.read_csv('backend/data/output/output.csv')
# Sort the dataframe by date
df = df.sort_values('Date')

# Create a new column that combines the "Class with Section", "Group (A,B)", "Time Slot", and "Lab Number" columns
df['Display Format'] = df['Class with Section'] + ' (' + df['Group (A,B,C,D)'] + ') : ' + df['Time Slot'] + ' ' + df['Lab Number']

# Display the dataframe
print(df[['Date', 'Display Format']])
# Out:
#            Date                            Display Format
# 67   2024-03-28    21AML-1 (B) : 1:00 PM - 2:40 PM D2-412
# 70   2024-03-28    21AML-6 (B) : 1:00 PM - 2:40 PM D2-412
# 69   2024-03-28    21AML-6 (A) : 1:00 PM - 2:40 PM D2-412
# 68   2024-03-28   21AML-12 (B) : 1:00 PM - 2:40 PM D2-412
# 133  2024-03-28    21BDA-1 (A) : 1:00 PM - 2:40 PM D2-412
# ..          ...                                       ...
# 90   2024-03-30   21BCC-2 (A) : 9:30 AM - 11:10 AM D2-411
# 91   2024-03-30   21BDA-1 (A) : 9:30 AM - 11:10 AM D2-411
# 92   2024-03-30   21BDA-2 (A) : 9:30 AM - 11:10 AM D2-411
# 18   2024-03-30  21AML-12 (B) : 9:30 AM - 11:10 AM D2-411
# 0    2024-03-30  21AML-11 (B) : 9:30 AM - 11:10 AM D2-411
#
# [135 rows x 2 columns]

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('../data/output/output.csv')

# Create a new column that combines the desired fields in the desired format
df['Formatted Data'] = df['Date'] + ' ' +df['Class with Section'] + ' (' + df['Group (A,B,C,D)'] + ') : ' +  df['Lab Number'] + ' ' + df['Time Slot'] + ' ' + df['Internal Examiner'] + ' (' + df['External Examiner'] + ')'

# Sort the DataFrame by 'Date', 'Time Slot', 'Internal Examiner', and 'External Examiner'
df = df.sort_values(['Date', 'Time Slot', 'External Examiner'])


# Fetch all the values from the 'Formatted Data' column
formatted_data_values = df['Formatted Data'].values

# Print the formatted data values
for value in formatted_data_values:
    print(value)
# Out:
# 2024-04-25 20BCC-1 (A) : D2-306 11:15 AM - 12:45 PM Dr. Monika Singh (Ms. Rubbina)
# 2024-04-25 22BCC-2 (A) : D2-207 11:15 AM - 12:45 PM ANKUR GUPTA (Shubham Banik)
# 2024-04-25 21BCC-1 (A) : D2-207 1:15 PM - 2:45 PM Shubham Banik (Dr. Dhawan Singh)
# 2024-04-25 20BCC-1 (B) : D2-306 1:15 PM - 2:45 PM Dr. Monika Singh (Dr. Ranjan Walia)
# 2024-04-25 20BCC-2 (B) : D2-306 3:00 PM - 4:30 PM Dr. Monika Singh (ANKUR GUPTA)
# 2024-04-25 21BCC-1 (A) : D2-207 3:00 PM - 4:30 PM Ms. Bhavna Nayyar (Dr. Deepti Sharma)
# 2024-04-25 22BCC-1 (A) : D2-207 9:30 AM - 11:00 AM ANKUR GUPTA (Ms. Geetanjali Pandey)
# 2024-04-25 21BCC-2 (A) : D2-306 9:30 AM - 11:00 AM Shubham Banik (Ms. Pavandeep Kaur)
# 2024-04-26 20BCC-1 (A) : D2-306 11:15 AM - 12:45 PM Dr. Deepti Sharma (ANKUR GUPTA)
# 2024-04-26 22BCC-2 (A) : D2-207 11:15 AM - 12:45 PM Ms. Geetanjali Pandey (Ms. Pavandeep Kaur)
# 2024-04-26 21BCC-1 (B) : D2-207 1:15 PM - 2:45 PM Shubham Banik (Ms. Bhavna Nayyar)
# ...

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('../data/output/output.csv')

# Create a new column that combines the desired fields in the desired format
df['Formatted Data'] = df['Date'] + ' ' +df['Class with Section'] + ' (' + df['Group (A,B,C,D)'] + ') : ' +  df['Lab Number'] + ' ' + df['Time Slot'] + ' ' + df['Internal Examiner'] + ' (' + df['External Examiner'] + ')'

# Sort the DataFrame by 'Date', 'Time Slot', 'Internal Examiner', and 'External Examiner'
df = df.sort_values(['Date', 'Class with Section'])

# Remove rows where the internal examiner is the same as the external examiner for the same time slot on the same day
df = df[~((df['Date'] == df['Date'].shift()) & (df['Time Slot'] == df['Time Slot'].shift()) & ((df['Internal Examiner'] == df['External Examiner'].shift()) | (df['External Examiner'] == df['Internal Examiner'].shift())))]

# Fetch all the values from the 'Formatted Data' column
formatted_data_values = df['Formatted Data'].values

# Print the formatted data values
for value in formatted_data_values:
    print(value)
# Out:
# 2024-04-25 20BCC-1 (A) : D2-306 1:15 PM - 2:45 PM Dr. Deepti Sharma (Dr. Ankit Garg)
# 2024-04-25 20BCC-2 (A) : D2-306 3:00 PM - 4:30 PM Dr. Monika Singh (Shubham Banik)
# 2024-04-25 20BCC-2 (A) : D2-307 9:30 AM - 11:00 AM Dr. Ranjan Walia (Dr. Ankit Garg)
# 2024-04-25 21BCC-1 (A) : D2-207 1:15 PM - 2:45 PM Shubham Banik (ANKUR GUPTA)
# 2024-04-25 21BCC-1 (A) : D2-207 3:00 PM - 4:30 PM Ms. Bhavna Nayyar (Ms. Rubbina)
# 2024-04-25 21BCC-2 (A) : D2-306 9:30 AM - 11:00 AM Shubham Banik (ANKUR GUPTA)
# 2024-04-25 21BCC-2 (A) : D2-306 11:15 AM - 12:45 PM Ms. Bhavna Nayyar (Ms. Geetanjali Pandey)
# 2024-04-25 22BCC-1 (A) : D2-207 9:30 AM - 11:00 AM ANKUR GUPTA (Ms. Rubbina)
# 2024-04-25 22BCC-2 (A) : D2-207 11:15 AM - 12:45 PM ANKUR GUPTA (Ms. Geetanjali Pandey)
# 2024-04-26 20BCC-1 (B) : D2-306 1:15 PM - 2:45 PM Dr. Deepti Sharma (Ms. Geetanjali Pandey)
# 2024-04-26 20BCC-2 (B) : D2-306 3:00 PM - 4:30 PM Dr. Monika Singh (Dr. Ankit Garg)
# ...

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('../data/output/output.csv')

# Create a new column that combines the desired fields in the desired format
df['Formatted Data'] = df['Date'] + ' ' +df['Class with Section'] + ' (' + df['Group (A,B,C,D)'] + ') : ' +  df['Lab Number'] + ' ' + df['Time Slot'] + ' ' + df['Internal Examiner'] + ' (' + df['External Examiner'] + ')'

# Sort the DataFrame by 'Date', 'Time Slot', 'Internal Examiner', and 'External Examiner'
df = df.sort_values(['Date', 'Time Slot', 'Internal Examiner', 'External Examiner'])

# Remove rows where the internal examiner is the same as the external examiner for the same time slot on the same day
df = df[~((df['Date'] == df['Date'].shift()) & (df['Time Slot'] == df['Time Slot'].shift()) & ((df['Internal Examiner'] == df['External Examiner'].shift()) | (df['External Examiner'] == df['Internal Examiner'].shift())))]

# Remove rows where the external examiner is the same for the same time slot on the same day
df = df.drop_duplicates(subset=['Date', 'Time Slot', 'External Examiner'], keep=False)

# Fetch all the values from the 'Formatted Data' column
formatted_data_values = df['Formatted Data'].values

# Print the formatted data values
for value in formatted_data_values:
    print(value)
# Out:
# 2024-04-25 20BCC-1 (A) : D2-306 1:15 PM - 2:45 PM Dr. Deepti Sharma (Dr. Ankit Garg)
# 2024-04-25 21BCC-1 (A) : D2-207 1:15 PM - 2:45 PM Shubham Banik (ANKUR GUPTA)
# 2024-04-25 20BCC-2 (A) : D2-306 3:00 PM - 4:30 PM Dr. Monika Singh (Shubham Banik)
# 2024-04-25 21BCC-1 (A) : D2-207 3:00 PM - 4:30 PM Ms. Bhavna Nayyar (Ms. Rubbina)
# 2024-04-25 22BCC-1 (A) : D2-207 9:30 AM - 11:00 AM ANKUR GUPTA (Ms. Rubbina)
# 2024-04-25 20BCC-2 (A) : D2-307 9:30 AM - 11:00 AM Dr. Ranjan Walia (Dr. Ankit Garg)
# 2024-04-25 21BCC-2 (A) : D2-306 9:30 AM - 11:00 AM Shubham Banik (ANKUR GUPTA)
# 2024-04-26 21BCC-2 (B) : D2-306 11:15 AM - 12:45 PM Ms. Bhavna Nayyar (Dr. Ankit Garg)
# 2024-04-26 22BCC-2 (A) : D2-207 11:15 AM - 12:45 PM Ms. Geetanjali Pandey (ANKUR GUPTA)
# 2024-04-26 20BCC-1 (B) : D2-306 1:15 PM - 2:45 PM Dr. Deepti Sharma (Ms. Geetanjali Pandey)
# 2024-04-26 21BCC-1 (B) : D2-207 1:15 PM - 2:45 PM Shubham Banik (Ms. Rubbina)
# ...

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('../data/output/output1.csv', encoding='ISO-8859-1')

# Create a new column that combines the desired fields in the desired format
df['Formatted Data'] = df['Date'] + ' ' +df['Class with Section'] + ' (' + df['Group'] + ') : ' +  df['Lab Number'] + ' ' + df['Time Slot'] + ' ' + df['Internal Examiner'] + ' (' + df['External Examiner'] + ')'

# Sort the DataFrame by 'Lab Number' and 'Date'
df = df.sort_values(['Date', 'Lab Number'])

# Fetch all the values from the 'Formatted Data' column
formatted_data_values = df['Formatted Data'].values

# Print the formatted data values
for value in formatted_data_values:
    print(value)
# Out:
# 2024-04-25 21BIT-1 (B) : D2-207 9:30 AM - 11:00 AM Dr. Sonal Rattan (Dr. Jitender )
# 2024-04-25 20BIT-1 (B) : D2-207 11:15 AM - 12:45 PM Mr. Gaurav Soni (Dr. navjeet Kaur)
# 2024-04-25 22BDA-1 (A) : D2-207 1:15 PM - 2:45 PM Mr. Pulkit dwivedi (Ms Ravneet Kaur)
# 2024-04-25 20AML 4 (B) : D2-207 3:00 PM - 4:30 PM Dr. Amit Kukker (Mr Namit Chawla)
# 2024-04-25 22BCC-2 (A) : D2-306 9:30 AM - 11:00 AM ANKUR GUPTA (Prabjot Singh Bali)
# 2024-04-25 20BCC-1 (A) : D2-306 11:15 AM - 12:45 PM Dr. Deepti Sharma (Dr. Jitender Kaushal)
# 2024-04-25 20BCC-2 (B) : D2-306 1:15 PM - 2:45 PM Dr. Deepti Sharma (Dr. Vineet Mehan)
# 2024-04-25 21BIS-1 (A) : D2-306 3:00 PM - 4:30 PM Mr Swapnil Raj (Dayal Chandra Sati)
# 2024-04-25 20AML 1 (B) : D2-307 9:30 AM - 11:00 AM Dr. U. Hariharan (Dr. Kamaljeet Saini)
# 2024-04-25 21AML-1 (A) : D2-307 11:15 AM - 12:45 PM LATA GUPTA (Mr Yogiraj Bhale)
# 2024-04-25 21AML-12 (A) : D2-307 1:15 PM - 2:45 PM Mr.Jagjit Singh (Ms. Upasana Tiwari)
# ...

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('../data/output/output.csv')

# Parse 'Date' column as datetime
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')  # Adjust the format according to your data

# Create a new column that combines the desired fields in the desired format
df['Formatted Data'] = df['Date'].dt.strftime('%Y-%m-%d') + ' ' + df['Class with Section'] + ' (' + df['Group (A,B,C,D)'] + ') : ' + df['Lab Number'] + ' ' + df['Time Slot'] + ' ' + df['Internal Examiner'] + ' (' + df['External Examiner'] + ')'

# Sort the DataFrame by 'Date', 'Time Slot', 'Internal Examiner', and 'External Examiner'
df = df.sort_values(['Date', 'Time Slot', 'Internal Examiner', 'External Examiner'])

# Remove rows where the internal examiner is the same as the external examiner for the same time slot on the same day
df = df[~((df['Date'] == df['Date'].shift()) & (df['Time Slot'] == df['Time Slot'].shift()) & ((df['Internal Examiner'] == df['External Examiner'].shift()) | (df['External Examiner'] == df['Internal Examiner'].shift())))]

# Remove rows where the external examiner is the same for the same time slot on the same day
df = df.drop_duplicates(subset=['Date', 'Time Slot', 'External Examiner'], keep=False)

# Ensure that no unique class and section, group have more than 3 practicals per date
df = df[df.groupby(['Date', 'Class with Section', 'Group (A,B,C,D)']).cumcount() < 3]

# Ensure that no two practicals are consecutive
df['Time Slot'] = pd.to_datetime(df['Time Slot'], errors='coerce', format='%I:%M %p')  # Adjust the format according to your data
df = df.dropna(subset=['Time Slot'])  # Drop rows where parsing failed
df = df.sort_values(['Date', 'Class with Section', 'Group (A,B,C,D)', 'Time Slot'])
df = df[~(df['Time Slot'] - df['Time Slot'].shift() < pd.Timedelta(minutes=30))]

# Fetch all the values from the 'Formatted Data' column
formatted_data_values = df['Formatted Data'].values

# Print the formatted data values
for value in formatted_data_values:
    print(value)

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('../data/output/output.csv')

# Parse 'Date' column as datetime
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')  # Adjust the format according to your data

# Create a new column that combines the desired fields in the desired format
df['Formatted Data'] = df['Date'].dt.strftime('%Y-%m-%d') + ' ' + df['Class with Section'] + ' (' + df['Group (A,B,C,D)'] + ') : ' + df['Lab Number'] + ' ' + df['Time Slot'] + ' ' + df['Internal Examiner'] + ' (' + df['External Examiner'] + ')'

# Sort the DataFrame by 'Date', 'Time Slot', 'Internal Examiner', and 'External Examiner'
df = df.sort_values(['Date', 'Time Slot', 'Internal Examiner', 'External Examiner'])

# Remove rows where the internal examiner is the same as the external examiner for the same time slot on the same day
df = df[~((df['Date'] == df['Date'].shift()) & (df['Time Slot'] == df['Time Slot'].shift()) & ((df['Internal Examiner'] == df['External Examiner'].shift()) | (df['External Examiner'] == df['Internal Examiner'].shift())))]

# Remove rows where the external examiner is the same for the same time slot on the same day
df = df.drop_duplicates(subset=['Date', 'Time Slot', 'External Examiner'], keep=False)

# Ensure that no unique class and section, group have more than 3 practicals per date
df = df[df.groupby(['Date', 'Class with Section', 'Group (A,B,C,D)']).cumcount() < 3]

# Ensure that no two practicals are consecutive
df['Time Slot'] = pd.to_datetime(df['Time Slot'], errors='coerce', format='%I:%M %p')  # Adjust the format according to your data
df = df.dropna(subset=['Time Slot'])  # Drop rows where parsing failed
df = df.sort_values(['Date', 'Class with Section', 'Group (A,B,C,D)', 'Time Slot'])
df = df[~(df['Time Slot'] - df['Time Slot'].shift() < pd.Timedelta(minutes=30))]

# Print the DataFrame in a tabular form
print(df.to_string(index=False))
# Out:
# Empty DataFrame
# Columns: [Sr No, Branch, Semester , Subject Name, Subject Code, Class with Section, Group (A,B,C,D), Total Students, Internal Examiner, EMP CODE, Lab Number, Time Slot, Date, External Examiner, Formatted Data]
# Index: []

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('../data/output/output.csv')

# Parse 'Date' and 'Time Slot' columns as datetime
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')  # Adjust the format according to your data
df['Time Slot'] = pd.to_datetime(df['Time Slot'], errors='coerce', format='%I:%M %p')  # Adjust the format according to your data
df = df.dropna(subset=['Time Slot'])  # Drop rows where parsing failed

# Create a new column that combines the desired fields in the desired format
df['Formatted Data'] = df['Date'].dt.strftime('%Y-%m-%d') + ' ' + df['Class with Section'] + ' (' + df['Group (A,B,C,D)'] + ') : ' + df['Lab Number'] + ' ' + df['Time Slot'].dt.strftime('%I:%M %p') + ' ' + df['Internal Examiner'] + ' (' + df['External Examiner'] + ')'

# Sort the DataFrame by 'Date', 'Class with Section', 'Group (A,B,C,D)', and 'Time Slot'
df = df.sort_values(['Date', 'Class with Section', 'Group (A,B,C,D)', 'Time Slot'])

# Ensure that no unique class and section, group have more than 3 practicals per date
df = df[df.groupby(['Date', 'Class with Section', 'Group (A,B,C,D)']).cumcount() < 3]

# Ensure that no two practicals are consecutive
df = df[~(df['Time Slot'] - df['Time Slot'].shift() < pd.Timedelta(minutes=30))]

# Fetch all the values from the 'Formatted Data' column
formatted_data_values = df['Formatted Data'].values

# Print the DataFrame in a tabular form
print(df.to_string(index=False))
# Out:
# Empty DataFrame
# Columns: [Sr No, Branch, Semester , Subject Name, Subject Code, Class with Section, Group (A,B,C,D), Total Students, Internal Examiner, EMP CODE, Lab Number, Time Slot, Date, External Examiner, Formatted Data]
# Index: []

# %%
# Filter the dataframe based on the same time slot, lab no., and date
filtered_df = df[df['Formatted Data'].isin(formatted_data_values)]

# Get the unique class with section (group(a,b)) values
unique_class_section = filtered_df['Class with Section'].unique()

# Print the unique class with section (group(a,b)) values
for class_section in unique_class_section:
    print(class_section)
# Out:
# 21AML-1
# 21AML-10
# 21AML-11
# 21AML-12
# 21AML-2
# 21AML-3
# 21AML-4
# 21AML-5
# 21AML-6
# 21AML-7
# 21AML-8
# 21AML-9
# 21BCB-1
# 21BCC-1
# 21BCC-2
# 21BCD-1
# 21BCG-1
# 21BDA-1
# 21BDA-2
# 21BIS-1
# 21BIS-2
# 21BIT-1
# 21CBS-1

# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel('../data/input/ClassList.xlsx', sheet_name='Faculty details')

# Fetch all the values of the column "Name of Faculty"
name_of_faculty_values = df['Name of Faculty'].values

# Print the values
for value in name_of_faculty_values:
    print(value)
# Out:
# Dr. Mandeep Tinna
# Dr Nitin Jain
# Dr Krishnendu Rarhi
# Mr Pramod Vishwakarma
# Mr Gurpreet Singh
# Dr Monica Luthra
# Mr Digvijay Puri
# Mr Yogiraj Bhale
# Dr Monika Singh
# Dr Hariharan
# Dr Deepak Kumar
# Ms Shivani Aggarwal
# Dr Gurwinder Singh
# Mr Harun
# Mr Namit Chawla
# Ms Yashika Sharma
# Ms Shweta
# Mr Saurabh Singhal
# Mr Abhishek Ankur
# Dr Vijay Bhardwaj
# Mr.Siddharth Kumar
# Ms Merry
# Mr Swapnil Raj
# Dr Vineet Mehan
# Ms Neeru Bala
# Ms. Shubhangi Mishra
# Mr. Nirmalya Basu
# Ms. Pragatie Chawla
# Mr Dayal Chandra Sati
# Ms.Lata Gupta
# Mr.Anil Manohar Dogra
# Mr.Pulkit Duivedi
# Mr. Kushagra Agarwal
# Mr. Bharat Tripathi
# Dr. Madan Lal Saini
# Mr Sant Kumar Maurya
# Dr.Priyanka Kaushik
# Mr.Krishna Kaushal Singh
# Mr Mohit Lalit
# Ms Amanpreet Kaur
# Dr Mahadev
# Ms Ravneet Kaur
# Dr Amit Vajpayee
# Dr Deepti Sharma
# Ms. Shaveta Jain
# Dr Alankrita Aggarwal
# Dr Jitender
# Ms Mansi Kajal
# Mr.Aadi Partap Singh
# Mr Aaskaran Bishnoi
# Dr Geeta Rani
# ...

# %%
import random

def generate_unique_examiner_pairs(all_names, num_schedules):
    # List to store generated schedules
    schedules = []

    # Generate unique exam schedules
    for _ in range(num_schedules):
        # Randomly select two different examiners
        internal_examiner, external_examiner = random.sample(all_names, 2)
        schedules.append((internal_examiner, external_examiner))

    return schedules

# List of all possible examiners
all_names = ['Examiner1', 'Examiner2', 'Examiner3', 'Examiner4', 'Examiner5']

# Number of exam schedules to generate
num_schedules = 10

# Generate and print unique examiner pairs
schedules = generate_unique_examiner_pairs(all_names, num_schedules)
for i, (internal_examiner, external_examiner) in enumerate(schedules, start=1):
    print(f"Schedule {i}:")
    print(f"Internal Examiner: {internal_examiner}")
    print(f"External Examiner: {external_examiner}")
    print()
# Out:
# Schedule 1:
# Internal Examiner: Examiner3
# External Examiner: Examiner2
#
# Schedule 2:
# Internal Examiner: Examiner2
# External Examiner: Examiner1
#
# Schedule 3:
# Internal Examiner: Examiner3
# External Examiner: Examiner5
#
# Schedule 4:
# Internal Examiner: Examiner1
# External Examiner: Examiner2
#
# Schedule 5:
# Internal Examiner: Examiner4
# External Examiner: Examiner1
#
# Schedule 6:
# Internal Examiner: Examiner1
# External Examiner: Examiner5
#
# Schedule 7:
# Internal Examiner: Examiner4
# External Examiner: Examiner5
#
# Schedule 8:
# Internal Examiner: Examiner5
# External Examiner: Examiner3
#
# Schedule 9:
# Internal Examiner: Examiner2
# External Examiner: Examiner4
#
# Schedule 10:
# Internal Examiner: Examiner2
# External Examiner: Examiner3

# %%
import pandas as pd
import random

# Read the data from the Excel file
df = pd.read_excel('../data/input/ClassList.xlsx')

# Get the list of all possible examiners
all_names = df['Internal Examiner'].unique().tolist()

def generate_unique_examiner_pairs(all_names, num_schedules):
    # List to store generated schedules
    schedules = []

    # Generate unique exam schedules
    for _ in range(num_schedules):
        # Randomly select two different examiners
        internal_examiner, external_examiner = random.sample(all_names, 2)
        schedules.append((internal_examiner, external_examiner))

    return schedules

# Number of exam schedules to generate
num_schedules = len(df)

# Generate and print unique examiner pairs
schedules = generate_unique_examiner_pairs(all_names, num_schedules)
for i, (internal_examiner, external_examiner) in enumerate(schedules, start=1):
    print(f"Schedule {i}:")
    print(f"Internal Examiner: {internal_examiner}")
    print(f"External Examiner: {external_examiner}")
    print()
# Out:
# Schedule 1:
# Internal Examiner: ANKUR GUPTA
# External Examiner: Ms. Pavandeep Kaur
#
# Schedule 2:
# Internal Examiner: Dr. Deepti Sharma
# External Examiner: Ms. Geetanjali Pandey
#
# Schedule 3:
# Internal Examiner: Dr. Ankit Garg
# External Examiner: Dr. Deepti Sharma
#
# Schedule 4:
# Internal Examiner: Ms. Pavandeep Kaur
# External Examiner: Shubham Banik
#
# Schedule 5:
# Internal Examiner: Dr. Ankit Garg
# External Examiner: Dr. Deepti Sharma
#
# Schedule 6:
# Internal Examiner: Ms. Geetanjali Pandey
# External Examiner: Dr. Deepti Sharma
#
# Schedule 7:
# Internal Examiner: Ms. Bhavna Nayyar
# External Examiner: Ms. Geetanjali Pandey
#
# Schedule 8:
# Internal Examiner: Dr. Ankit Garg
# External Examiner: Ms. Rubbina
#
# Schedule 9:
# Internal Examiner: Dr. Dhawan Singh
# External Examiner: Ms. Rubbina
#
# Schedule 10:
# Internal Examiner: Shubham Banik
# External Examiner: Ms. Rubbina
#
# Schedule 11:
# Internal Examiner: Dr. Dhawan Singh
# External Examiner: ANKUR GUPTA
# ...

# %%
import pandas as pd
import random

# Read the data from the Excel file
df = pd.read_excel('../data/input/ClassList.xlsx')

# Get the list of all possible examiners
all_names = df['Internal Examiner'].unique().tolist()

def generate_unique_examiner_pairs(all_names, num_schedules):
    # DataFrame to store generated schedules
    schedules_df = pd.DataFrame(columns=['Schedule', 'Internal Examiner', 'External Examiner'])

    # Generate unique exam schedules
    for i in range(num_schedules):
        # Randomly select two different examiners
        internal_examiner, external_examiner = random.sample(all_names, 2)
        schedules_df = schedules_df.append({'Schedule': i+1, 'Internal Examiner': internal_examiner, 'External Examiner': external_examiner}, ignore_index=True)

    return schedules_df

# Number of exam schedules to generate
num_schedules = len(df)

# Generate and print unique examiner pairs
schedules_df = generate_unique_examiner_pairs(all_names, num_schedules)
print(schedules_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6496\246538795.py in ?()
#      22 # Number of exam schedules to generate
#      23 num_schedules = len(df)
#      24
#      25 # Generate and print unique examiner pairs
# ---> 26 schedules_df = generate_unique_examiner_pairs(all_names, num_schedules)
#      27 print(schedules_df)
#
# ~\AppData\Local\Temp\ipykernel_6496\246538795.py in ?(all_names, num_schedules)
#      14     # Generate unique exam schedules
#      15     for i in range(num_schedules):
#      16         # Randomly select two different examiners
#      17         internal_examiner, external_examiner = random.sample(all_names, 2)
# ---> 18         schedules_df = schedules_df.append({'Schedule': i+1, 'Internal Examiner': internal_examiner, 'External Examiner': external_examiner}, ignore_index=True)
#      19
# ...

# %%
import pandas as pd
import random

# Read the data from the Excel file
df = pd.read_excel('../data/input/ClassList.xlsx')

# Get the list of all possible examiners
all_names = df['Internal Examiner'].unique().tolist()

def generate_unique_examiner_pairs(all_names, num_schedules):
    # DataFrame to store generated schedules
    schedules_list = []

    # Generate unique exam schedules
    for i in range(num_schedules):
        # Randomly select two different examiners
        internal_examiner, external_examiner = random.sample(all_names, 2)
        schedules_list.append({'Schedule': i + 1, 'Internal Examiner': internal_examiner, 'External Examiner': external_examiner})

    return pd.DataFrame(schedules_list)

# Number of exam schedules to generate
num_schedules = len(df)

# Generate and print unique examiner pairs
schedules_df = generate_unique_examiner_pairs(all_names, num_schedules)
print(schedules_df)
# Out:
#     Schedule      Internal Examiner      External Examiner
# 0          1  Ms. Geetanjali Pandey            Ms. Rubbina
# 1          2         Dr. Ankit Garg     Ms. Pavandeep Kaur
# 2          3         Dr. Ankit Garg       Dr. Dhawan Singh
# 3          4      Dr. Deepti Sharma            ANKUR GUPTA
# 4          5       Dr. Dhawan Singh      Dr. Deepti Sharma
# 5          6          Shubham Banik       Dr. Monika Singh
# 6          7          Shubham Banik  Ms. Geetanjali Pandey
# 7          8     Ms. Pavandeep Kaur       Dr. Dhawan Singh
# 8          9       Dr. Dhawan Singh  Ms. Geetanjali Pandey
# 9         10       Dr. Monika Singh  Ms. Geetanjali Pandey
# 10        11            Ms. Rubbina         Dr. Ankit Garg
# 11        12       Dr. Dhawan Singh          Shubham Banik
# 12        13            ANKUR GUPTA         Dr. Ankit Garg
# 13        14          Shubham Banik       Dr. Ranjan Walia
# 14        15       Dr. Ranjan Walia       Dr. Dhawan Singh
# ...

# %%
import pandas as pd
import random

# Read the data from the Excel file
df = pd.read_excel('../data/input/ClassList.xlsx')

# Get the list of all possible examiners
all_names = df['Internal Examiner'].unique().tolist()

def generate_unique_examiner_pairs(all_names, num_schedules):
    # List to store generated schedules
    schedules = []

    # Generate unique exam schedules
    for i in range(num_schedules):
        # Randomly select two different examiners
        internal_examiner, external_examiner = random.sample(all_names, 2)
        schedules.append({'Schedule': i+1, 'Internal Examiner': internal_examiner, 'External Examiner': external_examiner})

    # Convert list of dictionaries to DataFrame
    schedules_df = pd.DataFrame(schedules)

    return schedules_df

# Number of exam schedules to generate
num_schedules = len(df)

# Generate and print unique examiner pairs
schedules_df = generate_unique_examiner_pairs(all_names, num_schedules)
print(schedules_df)
# Out:
#     Schedule      Internal Examiner      External Examiner
# 0          1  Ms. Geetanjali Pandey          Shubham Banik
# 1          2       Dr. Dhawan Singh      Dr. Deepti Sharma
# 2          3       Dr. Monika Singh          Shubham Banik
# 3          4       Dr. Monika Singh       Dr. Dhawan Singh
# 4          5      Dr. Deepti Sharma     Ms. Pavandeep Kaur
# 5          6       Dr. Ranjan Walia         Dr. Ankit Garg
# 6          7  Ms. Geetanjali Pandey            ANKUR GUPTA
# 7          8          Shubham Banik            ANKUR GUPTA
# 8          9          Shubham Banik       Dr. Dhawan Singh
# 9         10     Ms. Pavandeep Kaur            Ms. Rubbina
# 10        11          Shubham Banik       Dr. Ranjan Walia
# 11        12      Ms. Bhavna Nayyar       Dr. Monika Singh
# 12        13       Dr. Ranjan Walia            ANKUR GUPTA
# 13        14       Dr. Dhawan Singh         Dr. Ankit Garg
# 14        15       Dr. Monika Singh       Dr. Dhawan Singh
# ...

# %%
import pandas as pd
import random

# Read the data from the Excel file
df = pd.read_excel('../data/input/ClassList.xlsx')

# Get the list of all possible examiners
all_names = df['Internal Examiner'].unique().tolist()

def generate_unique_examiner_pairs(all_names, num_schedules):
    # List to store generated schedules
    schedules = []

    # Generate unique exam schedules
    for i in range(num_schedules):
        # Randomly select two different examiners
        internal_examiner, external_examiner = random.sample(all_names, 2)
        schedules.append({'Schedule': i+1, 'Internal Examiner': internal_examiner, 'External Examiner': external_examiner})

    # Convert list of dictionaries to DataFrame
    schedules_df = pd.DataFrame(schedules)

    return schedules_df

# Number of exam schedules to generate
num_schedules = len(df)

# Generate and print unique examiner pairs
schedules_df = generate_unique_examiner_pairs(all_names, num_schedules)

# Filter the DataFrame to only include schedules with a specific internal or external examiner
specific_examiner = 'Examiner Name'
filtered_schedules_df = schedules_df.query("`Internal Examiner` == @specific_examiner or `External Examiner` == @specific_examiner")

print(filtered_schedules_df)
# Out:
# Empty DataFrame
# Columns: [Schedule, Internal Examiner, External Examiner]
# Index: []

# %%
import pandas as pd
import random

# Read the data from the Excel file
df = pd.read_excel('../data/input/ClassList.xlsx')

# Get the list of all possible examiners
all_names = df['Internal Examiner'].unique().tolist()

def generate_unique_examiner_pairs(all_names, num_schedules):
    # List to store generated schedules
    schedules = []

    # Generate unique exam schedules
    for i in range(num_schedules):
        # Randomly select two different examiners
        internal_examiner, external_examiner = random.sample(all_names, 2)
        schedules.append({'Schedule': i+1, 'Internal Examiner': internal_examiner, 'External Examiner': external_examiner})

    # Convert list of dictionaries to DataFrame
    schedules_df = pd.DataFrame(schedules)

    return schedules_df

# Number of exam schedules to generate
num_schedules = len(df)

# Generate and print unique examiner pairs
schedules_df = generate_unique_examiner_pairs(all_names, num_schedules)

# Sort the DataFrame based on the internal examiner's name
sorted_schedules_df = schedules_df.sort_values(by='Internal Examiner')

print(sorted_schedules_df)
# Out:
#     Schedule      Internal Examiner      External Examiner
# 0          1            ANKUR GUPTA            Ms. Rubbina
# 1          2            ANKUR GUPTA      Ms. Bhavna Nayyar
# 26        27         Dr. Ankit Garg          Shubham Banik
# 15        16         Dr. Ankit Garg       Dr. Monika Singh
# 20        21      Dr. Deepti Sharma            Ms. Rubbina
# 10        11      Dr. Deepti Sharma       Dr. Ranjan Walia
# 11        12      Dr. Deepti Sharma            Ms. Rubbina
# 12        13      Dr. Deepti Sharma          Shubham Banik
# 30        31       Dr. Dhawan Singh       Dr. Ranjan Walia
# 5          6       Dr. Dhawan Singh            Ms. Rubbina
# 19        20       Dr. Dhawan Singh  Ms. Geetanjali Pandey
# 32        33       Dr. Dhawan Singh  Ms. Geetanjali Pandey
# 9         10       Dr. Dhawan Singh       Dr. Ranjan Walia
# 14        15       Dr. Monika Singh            ANKUR GUPTA
# 33        34       Dr. Ranjan Walia          Shubham Banik
# ...

# %%
import pandas as pd
import random

# Read the data from the Excel file
df = pd.read_excel('../data/input/ClassList.xlsx')

# Write the dataframe object into csv file
df.to_csv("../data/input/class.csv", index=None, header=True)

# Read csv file and convert into a dataframe object
df_csv = pd.DataFrame(pd.read_csv("../data/input/class.csv"))

# Get the list of all possible examiners
all_names = df['Internal Examiner'].unique().tolist()

def generate_unique_examiner_pairs(all_names, num_schedules):
    # List to store generated schedules
    schedules = []

    # Generate unique exam schedules
    for i in range(num_schedules):
        # Randomly select two different examiners
        internal_examiner, external_examiner = random.sample(all_names, 2)
        schedules.append({'Schedule': i+1, 'Internal Examiner': internal_examiner, 'External Examiner': external_examiner})

    # Convert list of dictionaries to DataFrame
    schedules_df = pd.DataFrame(schedules)

    return schedules_df

# Number of exam schedules to generate
num_schedules = len(df)

# Generate unique examiner pairs
schedules_df = generate_unique_examiner_pairs(all_names, num_schedules)

# Concatenate the dataframes along the columns axis
result = pd.concat([df_csv, schedules_df], axis=1)

print(result)
# Out:
#     Sr No Branch Semester                                        Subject Name  \
# 0       1     CC       4TH                  Design and Analysis of Algorithms
# 1       2     CC       4TH                  Design and Analysis of Algorithms
# 2       3     CC       4TH                              Programming in Python
# 3       4     CC       4TH                              Programming in Python
# 4       5     CC       4TH                  Design and Analysis of Algorithms
# 5       6     CC       4TH                              Programming in Python
# 6       7     CC      6TH                            Network Operating System
# 7       8     CC      6TH                            Network Operating System
# 8       9     CC      6TH                                  Technical Training
# 9      10     CC      6TH                                  Technical Training
# 10     11     CC      6TH                     Agile Development Methodologies
# ...

# %%
import pandas as pd
import random

# Read the data from the Excel file
df = pd.read_excel('../data/input/ClassList.xlsx')

# Write the dataframe object into csv file
df.to_csv("../data/input/class.csv", index=None, header=True)

# Read csv file and convert into a dataframe object
df_csv = pd.DataFrame(pd.read_csv("../data/input/class.csv"))

# Get the list of all possible examiners
all_names = df['Internal Examiner'].unique().tolist()

def generate_unique_examiner_pairs(all_names, num_schedules):
    # List to store generated schedules
    schedules = []

    # Generate unique exam schedules
    for i in range(num_schedules):
        # Randomly select two different examiners
        internal_examiner, external_examiner = random.sample(all_names, 2)
        schedules.append({'Schedule': i+1, 'Internal Examiner': internal_examiner, 'External Examiner': external_examiner})

    # Convert list of dictionaries to DataFrame
    schedules_df = pd.DataFrame(schedules)

    return schedules_df

# Number of exam schedules to generate
num_schedules = len(df)

# Generate unique examiner pairs
schedules_df = generate_unique_examiner_pairs(all_names, num_schedules)

# Concatenate the dataframes along the columns axis
result = pd.concat([schedules_df, df_csv], axis=1)

print(result)
# Out:
#     Schedule      Internal Examiner      External Examiner  Sr No Branch  \
# 0          1       Dr. Dhawan Singh      Ms. Bhavna Nayyar      1     CC
# 1          2            ANKUR GUPTA  Ms. Geetanjali Pandey      2     CC
# 2          3      Dr. Deepti Sharma         Dr. Ankit Garg      3     CC
# 3          4  Ms. Geetanjali Pandey         Dr. Ankit Garg      4     CC
# 4          5     Ms. Pavandeep Kaur         Dr. Ankit Garg      5     CC
# 5          6       Dr. Monika Singh            Ms. Rubbina      6     CC
# 6          7      Dr. Deepti Sharma     Ms. Pavandeep Kaur      7     CC
# 7          8      Dr. Deepti Sharma       Dr. Ranjan Walia      8     CC
# 8          9            ANKUR GUPTA  Ms. Geetanjali Pandey      9     CC
# 9         10            ANKUR GUPTA         Dr. Ankit Garg     10     CC
# 10        11  Ms. Geetanjali Pandey       Dr. Dhawan Singh     11     CC
# 11        12      Dr. Deepti Sharma       Dr. Ranjan Walia     12     CC
# ...

# %%
import csv
from itertools import product
import pandas as pd
from collections import defaultdict

xls = pd.ExcelFile('../data/input/ClassList.xlsx')

# Get the names of all worksheets in the Excel file
sheet_names = xls.sheet_names

# Exclude the 'Faculty details' worksheet
sheet_names.remove('Faculty details')

# Initialize an empty list to store the data from all worksheets
all_data = []

# Loop through each worksheet
for sheet_name in sheet_names:
    # Read the worksheet into a DataFrame
    df = pd.read_excel(xls, sheet_name)

    # Standardize the column names
    df.columns = ['Sr No', 'Branch', 'Semester', 'Subject Name', 'Subject Code', 'Class with Section', 'Group', 'Total Students', 'Internal Examiner', 'EMP Code']

    # Convert the DataFrame to a list of dictionaries
    data_list = df.to_dict('records')

    # Append the data list to all_data
    all_data.extend(data_list)
    
# Now all_data contains data from all worksheets
data = all_data
all_data
# Out:
# [{'Sr No': 1,
#   'Branch': 'CC',
#   'Semester': '4TH',
#   'Subject Name': 'Design and Analysis of Algorithms',
#   'Subject Code': '22CSH-282',
#   'Class with Section': '22BCC-1',
#   'Group': 'A',
#   'Total Students': 38,
#   'Internal Examiner': 'ANKUR GUPTA',
#   'EMP Code': 'E15733'},
#  {'Sr No': 2,
#   'Branch': 'CC',
#   'Semester': '4TH',
#   'Subject Name': 'Design and Analysis of Algorithms',
#   'Subject Code': '22CSH-282',
#   'Class with Section': '22BCC-1',
#   'Group': 'B',
#   'Total Students': 32,
#   'Internal Examiner': 'ANKUR GUPTA',
#   'EMP Code': 'E15733'},
#  {'Sr No': 3,
#   'Branch': 'CC',
#   'Semester': '4TH',
#   'Subject Name': 'Programming in Python',
#   'Subject Code': '22CSH-287',
#   'Class with Section': '22BCC-1',
#   'Group': 'A',
#   'Total Students': 38,
#   'Internal Examiner': 'Ms. Rubbina',
#   'EMP Code': 'E16582'},
#  {'Sr No': 4,
#   'Branch': 'CC',
#   'Semester': '4TH',
#   'Subject Name': 'Programming in Python',
# ...
